# %%
import pandas as pd
import json
import os
import pymongo
import pymatgen
import re
# Out:
# {'PMG_VASP_PSP_DIR': '~/local/pmg_psp/'}

# %%
client = pymongo.MongoClient()
entries = client.PyChemiaDB_OQMD12.pychemia_entries

# %%
ls = os.listdir('workfunctions/')

# %%
df = pd.DataFrame()
df['formula'] = ''
df['SPG'] = ''
df['International'] = ''
df['Termination'] = ''
df['direction'] = ''
df['Mismatch_A'] = ''
df['Mismatch_B'] = ''
df['Mismatch_Angle'] = ''
df['Workfunction'] = ''
df['Efermi'] = ''
df['icsd'] = ''
df['Link'] = ''
df['_id'] = ''
df['status'] = ''

for item in ls :
    rf = open('results/'+item,'r')
    data_mismatch = json.load(rf)
    rf.close()
    key_mismatch = [x for x in data_mismatch][0]
    if len(data_mismatch[key_mismatch]["[0, 0, 1]"]) != 0:
        direction = "[0, 0, 1]"
    elif len(data_mismatch[key_mismatch]["[0, 1, 0]"]) != 0:
        direction = "[0, 1, 0]"
    elif len(data_mismatch[key_mismatch]["[1, 0, 0]"]) != 0:
        direction = "[1, 0, 0]"
    Mismatch_A = data_mismatch[key_mismatch][direction]['mismatch'][0]
    Mismatch_B = data_mismatch[key_mismatch][direction]['mismatch'][1]
    Mismatch_Angle = data_mismatch[key_mismatch][direction]['mismatch'][2]
    _id = data_mismatch[key_mismatch]['_id']
    oqmd_id = re.findall('[0-9]*_[a-zA-z0-9]*_0*([1-9][0-9]*)',_id)[0]


    entry = entries.find_one({'_id':_id})
    path = entry['properties']['oqmd']['path']
    spg = entry['properties']['oqmd']['sym_dtset']['number']
    international = entry['properties']['oqmd']['sym_dtset']['international']
    st_dict = entry['structure']
    substrate = pymatgen.core.Structure(lattice=st_dict["cell"],
                                             species=st_dict['symbols'],coords=st_dict['positions'],coords_are_cartesian=True)
        
    formula = substrate.composition.reduced_formula
    if path != None and 'icsd' in path :
        icsd = True
    else :
        icsd = False
    rf = open('workfunctions/'+item,'r')
    data_wf = json.load(rf)
    rf.close()
    key_wf = [x for x in data_wf][0]
    for layer in data_wf[key_wf]:
        if data_wf[key_wf][layer] == "interrupted":
            continue
        efermi = data_wf[key_wf][layer]['efermi']
        status = data_wf[key_wf][layer]['status']
        workfunction = data_wf[key_wf][layer]['work-function']
        to_append = {'formula'     : formula,
                     'SPG'         : spg,
                     'International': international,
                     'Termination' : layer,
                     'direction'   : direction,
                     "Mismatch_A": Mismatch_A*100,
                     "Mismatch_B": Mismatch_B*100,
                     "Mismatch_Angle": Mismatch_Angle,
                     "Workfunction": workfunction,
                     "Efermi": efermi,
                     "icsd": icsd,
                     "Link": 'http://oqmd.org/materials/entry/'+ oqmd_id,
                     "_id": _id,
                     "status": status}
        df = df.append(to_append,ignore_index=True)

# %%
# Out:
#           formula  SPG International Termination  direction  Mismatch_A  \
# 0          HgAsO3    8            Cm     layer_0  [0, 0, 1]    0.004404
# 1          HgAsO3    8            Cm     layer_1  [0, 0, 1]    0.004404
# 2          HgAsO3    8            Cm     layer_2  [0, 0, 1]    0.004404
# 3          HgAsO3    8            Cm     layer_3  [0, 0, 1]    0.004404
# 4            SiSb  160           R3m     layer_0  [0, 0, 1]   -0.000327
# 5        Zr2TiAl2  139        I4/mmm     layer_0  [0, 0, 1]   -0.001288
# 6        Zr2TiAl2  139        I4/mmm     layer_1  [0, 0, 1]   -0.001288
# 7        Zr2TiAl2  139        I4/mmm     layer_2  [0, 0, 1]   -0.001288
# 8        Zr2TiAl2  139        I4/mmm     layer_3  [0, 0, 1]   -0.001288
# 9        Zr2TiAl2  139        I4/mmm     layer_4  [0, 0, 1]   -0.001288
# 10       Zr2TiAl2  139        I4/mmm     layer_5  [0, 0, 1]   -0.001288
# 11       Zr2TiAl2  139        I4/mmm     layer_6  [0, 0, 1]   -0.001288
# 12       Zr2TiAl2  139        I4/mmm     layer_7  [0, 0, 1]   -0.001288
# 13           NdZn  221         Pm-3m     layer_0  [0, 0, 1]    0.005425
# 14           NdZn  221         Pm-3m     layer_1  [0, 0, 1]    0.005425
# 15          BeIr3  221         Pm-3m     layer_0  [0, 0, 1]   -0.006174
# 16          BeIr3  221         Pm-3m     layer_1  [0, 0, 1]   -0.006174
# 17          BeIr3  221         Pm-3m     layer_2  [0, 0, 1]   -0.006174
# 18            YbP   38          Amm2     layer_0  [0, 0, 1]    0.007125
# 19            YbP   38          Amm2     layer_1  [0, 0, 1]    0.007125
# 20          TaCo3  160           R3m     layer_0  [0, 0, 1]   -0.000175
# 21          TaCo3  160           R3m     layer_1  [0, 0, 1]   -0.000175
# 22          TaCo3  160           R3m     layer_2  [0, 0, 1]   -0.000175
# 23    MgFe(Cu2B)2   99          P4mm     layer_0  [0, 0, 1]    0.003200
# 24    MgFe(Cu2B)2   99          P4mm     layer_1  [0, 0, 1]    0.003200
# 25    MgFe(Cu2B)2   99          P4mm     layer_2  [0, 0, 1]    0.003200
# 26    MgFe(Cu2B)2   99          P4mm     layer_3  [0, 0, 1]    0.003200
# 27    MgFe(Cu2B)2   99          P4mm     layer_4  [0, 0, 1]    0.003200
# 28    MgFe(Cu2B)2   99          P4mm     layer_5  [0, 0, 1]    0.003200
# 29       Nb2CuGe2  139        I4/mmm     layer_0  [0, 0, 1]   -0.002132
# ...           ...  ...           ...         ...        ...         ...
# 4570      NiPb2O3   44          Imm2    layer_10  [0, 0, 1]    0.046027
# 4571      NiPb2O3   44          Imm2     layer_2  [0, 0, 1]    0.046027
# 4572      NiPb2O3   44          Imm2     layer_3  [0, 0, 1]    0.046027
# 4573      NiPb2O3   44          Imm2     layer_4  [0, 0, 1]    0.046027
# 4574      NiPb2O3   44          Imm2     layer_5  [0, 0, 1]    0.046027
# 4575      NiPb2O3   44          Imm2     layer_6  [0, 0, 1]    0.046027
# 4576      NiPb2O3   44          Imm2     layer_7  [0, 0, 1]    0.046027
# 4577      NiPb2O3   44          Imm2     layer_8  [0, 0, 1]    0.046027
# 4578      NiPb2O3   44          Imm2     layer_9  [0, 0, 1]    0.046027
# 4579         NdBi   99          P4mm     layer_0  [0, 0, 1]    0.006886
# 4580         NdBi   99          P4mm     layer_1  [0, 0, 1]    0.006886
# 22     http://oqmd.org/materials/entry/344625  2_Co3Ta_00000000000000344625
# 23     http://oqmd.org/materials/entry/751303  4_B2Cu4FeMg_0000000000751303
# 24     http://oqmd.org/materials/entry/751303  4_B2Cu4FeMg_0000000000751303
# 25     http://oqmd.org/materials/entry/751303  4_B2Cu4FeMg_0000000000751303
# 26     http://oqmd.org/materials/entry/751303  4_B2Cu4FeMg_0000000000751303
# 27     http://oqmd.org/materials/entry/751303  4_B2Cu4FeMg_0000000000751303
# 28     http://oqmd.org/materials/entry/751303  4_B2Cu4FeMg_0000000000751303
# 29    http://oqmd.org/materials/entry/1213153  3_CuGe2Nb2_00000000001213153
# ...                                       ...                           ...
# 4570  http://oqmd.org/materials/entry/1036286  3_NiO3Pb2_000000000001036286
# 4571  http://oqmd.org/materials/entry/1036286  3_NiO3Pb2_000000000001036286
# 4572  http://oqmd.org/materials/entry/1036286  3_NiO3Pb2_000000000001036286
# 4573  http://oqmd.org/materials/entry/1036286  3_NiO3Pb2_000000000001036286
# 4574  http://oqmd.org/materials/entry/1036286  3_NiO3Pb2_000000000001036286
# 4575  http://oqmd.org/materials/entry/1036286  3_NiO3Pb2_000000000001036286
# 4576  http://oqmd.org/materials/entry/1036286  3_NiO3Pb2_000000000001036286
# 4577  http://oqmd.org/materials/entry/1036286  3_NiO3Pb2_000000000001036286
# 4578  http://oqmd.org/materials/entry/1036286  3_NiO3Pb2_000000000001036286
# 4579   http://oqmd.org/materials/entry/337248  2_BiNd_000000000000000337248
# 4580   http://oqmd.org/materials/entry/337248  2_BiNd_000000000000000337248
# 4581   http://oqmd.org/materials/entry/352446  3_CuO3W_00000000000000352446
# 4582   http://oqmd.org/materials/entry/352446  3_CuO3W_00000000000000352446
# 4583   http://oqmd.org/materials/entry/352446  3_CuO3W_00000000000000352446
# 4584   http://oqmd.org/materials/entry/352446  3_CuO3W_00000000000000352446
# 4585  http://oqmd.org/materials/entry/1202481  4_CeCo2O6Zn_0000000001202481
# 4586  http://oqmd.org/materials/entry/1202481  4_CeCo2O6Zn_0000000001202481
# 4587  http://oqmd.org/materials/entry/1202481  4_CeCo2O6Zn_0000000001202481
# 4588  http://oqmd.org/materials/entry/1202481  4_CeCo2O6Zn_0000000001202481
# 4589  http://oqmd.org/materials/entry/1202481  4_CeCo2O6Zn_0000000001202481
# 4590  http://oqmd.org/materials/entry/1202481  4_CeCo2O6Zn_0000000001202481
# 4591  http://oqmd.org/materials/entry/1202481  4_CeCo2O6Zn_0000000001202481
# 4592  http://oqmd.org/materials/entry/1237206  3_Mo2Pt2Ru_00000000001237206
# 4593  http://oqmd.org/materials/entry/1237206  3_Mo2Pt2Ru_00000000001237206
# 4594  http://oqmd.org/materials/entry/1237206  3_Mo2Pt2Ru_00000000001237206
# 4595  http://oqmd.org/materials/entry/1237206  3_Mo2Pt2Ru_00000000001237206
# 4596  http://oqmd.org/materials/entry/1237206  3_Mo2Pt2Ru_00000000001237206
# 4597  http://oqmd.org/materials/entry/1237206  3_Mo2Pt2Ru_00000000001237206
# 4598  http://oqmd.org/materials/entry/1237206  3_Mo2Pt2Ru_00000000001237206
# 4599  http://oqmd.org/materials/entry/1237206  3_Mo2Pt2Ru_00000000001237206
#
#          status
# 0     completed
# 1     completed
# 2     completed
# 3     completed
# 4     completed
# 5     completed
# 6     completed
# 7     completed
# 8     completed
# 9     completed
# 10    completed
# 11    completed
# 12    completed
# 13    completed
# 14    completed
# 15    completed
# 16    completed
# 17    completed
# 18    completed
# 19    completed
# 20    completed
# 21    completed
# 22    completed
# 23    completed
# 24    completed
# 25    completed
# 26    completed
# 27    completed
# 28    completed
# 29    completed
# ...         ...
# 4570  completed
# 4571  completed
# 4572  completed
# 4573  completed
# 4574  completed
# 4575  completed
# 4576  completed
# 4577  completed
# 4578  completed
# 4579  completed
# 4580  completed
# 4581  completed
# 4582  completed
# 4583  completed
# 4584  completed
# 4585  completed
# 4586  completed
# 4587  completed
# 4588  completed
# 4589  completed
# 4590  completed
# 4591  completed
# 4592  completed
# 4593  completed
# 4594  completed
# 4595  completed
# 4596  completed
# 4597  completed
# 4598  completed
# 4599  completed
#
# [4600 rows x 14 columns]

# %%
df.to_excel('final_results.xlsx')
